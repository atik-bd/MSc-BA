# %% [markdown]
# <a href="https://colab.research.google.com/github/atik-bd/MSc-BA/blob/main/Resume_Atik%20V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
resume = {
    "name": "Atik Mahbub",
    "contact": {
        "address": "9 Fernwood Park, Dublin 24, D24 X9X6, Ireland",
        "phone": "+353894156054",
        "email": "atikmahbub@gmail.com",
        "linkedin": "https://www.linkedin.com/in/atik-mahbub-04a2bb50/"
    },
    "professional_experience": [
        {
            "company": "Nestle Bangladesh PLC",
            "roles": [
                {
                    "title": "Area Sales Executive",
                    "dates": "May 2024 – January 2025",
                    "responsibilities": [
                        "Led team alignment with channel/customer plans",
                        "Executed Route-to-Market (RTM) strategies",
                        "Monitored distributor targets and performance"
                    ]
                },
                {
                    "title": "Senior Territory Officer",
                    "dates": "April 2021 – April 2024",
                    "responsibilities": [
                        "Drove sales growth through agile processes",
                        "Managed trade merchandising programs"
                    ]
                }
            ]
        },
        {
            "company": "Philip Morris Services India S. A",
            "roles": [
                {
                    "title": "Territory Sales Executive",
                    "dates": "January 2016 – March 2017",
                    "responsibilities": [
                        "Product launches and market expansion"
                    ]
                }
            ]
        }
    ],
    "education": [
        {
            "degree": "MSc in Business Analytics",
            "institution": "Dublin Business School",
            "dates": "January 2025 – Ongoing"
        },
        {
            "degree": "MBA (Marketing)",
            "institution": "North South University",
            "dates": "September 2020 – December 2022",
            "achievements": ["CGPA: 3.74 (Magna Cum Laude)"]
        }
    ],
    "certifications": [
        "Career Essentials in Business Analysis (Microsoft/LinkedIn)",
        "Leading Others (Rive-Reine S.A.)",
        "Digital Media Buying and Planning (Nestle Academy)"
    ],
    "awards": [
        "Winner - Growth Champion H1, 2023 (Nestle)",
        "Winner - RTM Optimization Award, 2022 (Nestle)"
    ]
}

# Function to print formatted resume
def print_resume(data):
    print(f"Name: {data['name']}\n")
    print("Contact Information:")
    for key, value in data['contact'].items():
        print(f"- {key.capitalize()}: {value}")

    print("\nProfessional Experience:")
    for exp in data['professional_experience']:
        print(f"\nCompany: {exp['company']}")
        for role in exp['roles']:
            print(f"\n  Role: {role['title']} ({role['dates']})")
            print("  Responsibilities:")
            for resp in role['responsibilities']:
                print(f"  - {resp}")

    print("\nEducation:")
    for edu in data['education']:
        print(f"\n- {edu['degree']}")
        print(f"  Institution: {edu['institution']}")
        print(f"  Dates: {edu['dates']}")
        if "achievements" in edu:
            print("  Achievements:")
            for ach in edu['achievements']:
                print(f"  - {ach}")

    print("\nCertifications:")
    for cert in data['certifications']:
        print(f"- {cert}")

    print("\nAwards:")
    for award in data['awards']:
        print(f"- {award}")

# Generate formatted output
print_resume(resume)
# Out:
# Name: Atik Mahbub
#
# Contact Information:
# - Address: 9 Fernwood Park, Dublin 24, D24 X9X6, Ireland
# - Phone: +353894156054
# - Email: atikmahbub@gmail.com
# - Linkedin: https://www.linkedin.com/in/atik-mahbub-04a2bb50/
#
# Professional Experience:
#
# Company: Nestle Bangladesh PLC
#
#   Role: Area Sales Executive (May 2024 – January 2025)
#   Responsibilities:
#   - Led team alignment with channel/customer plans
#   - Executed Route-to-Market (RTM) strategies
#   - Monitored distributor targets and performance
#
#   Role: Senior Territory Officer (April 2021 – April 2024)
#   Responsibilities:
#   - Drove sales growth through agile processes
#   - Managed trade merchandising programs
#
# Company: Philip Morris Services India S. A
#
#   Role: Territory Sales Executive (January 2016 – March 2017)
#   Responsibilities:
#   - Product launches and market expansion
#
# Education:
#
# - MSc in Business Analytics
#   Institution: Dublin Business School
#   Dates: January 2025 – Ongoing
# ...
